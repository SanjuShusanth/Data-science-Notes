# %% [markdown]
# [//]: # ({% raw %})
#
# #### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a web development Framework, used to create a web applications. It has the collection of libraries and modules that enables web application developers to create the web applications.
#
# Advantages of Flask Framework:
#
# * Flask is a simple Framework to create the web applications
#
# * It provides flexibility to the developers to expertiment with the libraries and Modules.
#
# * Uses Jinja2 Template engine.
#
# * It provide the strong web server gateway Interface.

# %% [markdown]
# #### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')

def func_name():
    return 'Hello World!'

if __name__ == '__main__':
    app.run(host = '0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.38:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [26/May/2023 13:38:20] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# * It is a technique use to map the URL with the dedicated function to perform the specific task.
# * Route command allows the developer to make manual entries, it binds the function to the URL path.

# %% [markdown]
# #### Q4.  Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
#
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)


@app.route('/')
def HomePage():
    return "Home Page"


@app.route('/welcome')
def ABC_Corporation():
    return 'Welcome to ABC Corporation'


@app.route('/detail1')
def details1():
    Info = {'Company Name': 'ABC Corporation',
            'Location': 'India',
            'Contact Detail': 9999999999}
    info_str = '\n'.join(f"{key}: {value}" for key, value in Info.items())
    return info_str


if __name__ == '__main__':
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.38:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [26/May/2023 13:38:51] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2023 13:39:04] "GET /detail1 HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# The `url_for()` function is used for URL building, it takes name of the view function as its first argument, and any number of keyword arguments, each corresponding to the variable part of the URL.

# %%
from flask import Flask, url_for

app = Flask(__name__)


@app.route('/')
def HomePage():
    return "Home Page"


@app.route('/welcome')
def ABC_Corporation():
    return 'Welcome to ABC Corporation'


@app.route('/detail1')
def details1():
    Info = {'Company Name': 'ABC Corporation',
            'Location': 'India',
            'Contact Detail': 9999999999}
    info_str = '\n'.join(f"{key}: {value}" for key, value in Info.items())
    return info_str


if __name__ == '__main__':
    with app.test_request_context():
        home_url = url_for('ABC_Corporation')
        details_url = url_for('details1')
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# [//]: # ({% endraw %})
